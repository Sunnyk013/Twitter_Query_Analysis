# %% [markdown]
# # How to Use the System ?
#
# __Follow these steps to use the system on your computer:__

# %% [markdown]
# __Step 1: Install Python and Required Libraries__

# %%
# pip install pandas
import pandas as pd
# This will install the pandas library, which is used for 
# handling and processing the dataset.

# %% [markdown]
# __Step 2: Prepare the Dataset__
# - Ensure that the dataset is in a .tsv (Tab-Separated Values) format. The system expects a dataset similar to correct_twitter_201904.tsv, with a structure containing columns like text, created_at, author_id, like_count, and place_id.
#
# - The dataset should be loaded into a pandas DataFrame using the following code:

# %%
df = pd.read_csv('correct_twitter_201904.tsv', sep='\t')
df
# Out:
#                         id           event                               ts1  \
# 0      1131594960443199488  britney_201904  2022-02-28 09:34:44.627023-05:00
# 1      1131594976750653440  britney_201904  2022-02-28 09:34:44.626921-05:00
# 2      1131589737955942405  britney_201904  2022-02-28 09:34:44.634058-05:00
# 3      1131594909469892610  britney_201904  2022-02-28 09:34:44.627125-05:00
# 4      1131594812694511617  britney_201904  2022-02-28 09:34:44.627227-05:00
# ...                    ...             ...                               ...
# 88032  1122977274352082944  britney_201904  2022-02-28 09:47:43.066500-05:00
# 88033  1122977257969127429  britney_201904  2022-02-28 09:47:43.066605-05:00
# 88034  1122977009347518466  britney_201904  2022-02-28 09:47:43.066708-05:00
# 88035  1122976878812442626  britney_201904  2022-02-28 09:47:43.066810-05:00
# 88036  1122976855647240203  britney_201904  2022-02-28 09:47:43.066921-05:00
#
#                                     ts2  from_stream  directly_from_stream  \
# 0      2022-02-28 09:34:44.627023-05:00         True                  True
# 1      2022-02-28 09:34:44.626921-05:00         True                  True
# 2      2022-02-28 09:34:44.634058-05:00         True                  True
# 3      2022-02-28 09:34:44.627125-05:00         True                  True
# 4      2022-02-28 09:34:44.627227-05:00         True                  True
# ...                                 ...          ...                   ...
# 88032  2022-02-28 09:47:43.066500-05:00         True                  True
# 88033  2022-02-28 09:47:43.066605-05:00         True                  True
# 88034  2022-02-28 09:47:43.066708-05:00         True                  True
# 88035  2022-02-28 09:47:43.066810-05:00         True                  True
# 88036  2022-02-28 09:47:43.066921-05:00         True                  True
#
#        from_search  directly_from_search  from_quote_search  \
# 0            False                 False              False
# 1            False                 False              False
# 2            False                 False              False
# 3            False                 False              False
# 4            False                 False              False
# ...            ...                   ...                ...
# 88032        False                 False              False
# 88033        False                 False              False
# 88034        False                 False              False
# 88035        False                 False              False
# 88036        False                 False              False
#
#        directly_from_quote_search  ...            retweeted  \
# 0                           False  ...  1130917791752757254
# 1                           False  ...                 None
# 2                           False  ...                 None
# 3                           False  ...  1130917791752757254
# 4                           False  ...  1130917791752757254
# ...                           ...  ...                  ...
# 88032                       False  ...  1122975837500989440
# 88033                       False  ...  1118942889785085958
# 88034                       False  ...                 None
# 88035                       False  ...  1122898327895519233
# 88036                       False  ...                 None
#
#        retweeted_author_id  retweeted_handle  retweeted_follower_count  \
# 0               3042894016          Iesbwian                     22760
# 1                     None              None                      None
# 2                     None              None                      None
# 3               3042894016          Iesbwian                     22760
# 4               3042894016          Iesbwian                     22760
# ...                    ...               ...                       ...
# 88032           2934938957   STORMISKELLYBAG                     13773
# 88033            613702825       keanuorange                      1422
# 88034                 None              None                      None
# 88035   846864187015888896      TheBlastNews                     11533
# 88036                 None              None                      None
#
#       mentioned_author_ids mentioned_handles  hashtags  \
# 0                     None              None      None
# 1                     None              None      None
# 2                     None              None      None
# 3                     None              None      None
# 4                     None              None      None
# ...                    ...               ...       ...
# 88032                 None              None      None
# 88033                 None              None      None
# 88034                 None              None      None
# 88035                 None              None      None
# 88036                 None              None      None
#
#                                                     urls media_keys  place_id
# 0                                                   None       None      None
# 1                                                   None       None      None
# 2                                                   None       None      None
# 3                                                   None       None      None
# 4                                                   None       None      None
# ...                                                  ...        ...       ...
# 88032                                               None       None      None
# 88033                                               None       None      None
# 88034                                               None       None      None
# 88035                                               None       None      None
# 88036  [{'end': 65, 'url': 'https://t.co/DcqjuqMJDK',...       None      None
#
# [88037 rows x 46 columns]

# %% [markdown]
# __Step 3: Cleaning The Data Set or analyzing Dataset
#
# - Data cleaning or data cleansing is the process of detecting, correcting or removing corrupt or inaccurate records from a data-set,table or database
#
# - It also refers to identifying incomplete, incorrect, inaccurate or irrelevant parts of the data and then replacing, modifying or deleting the dirty data

# %%
df.columns
# Out:
# Index(['id', 'event', 'ts1', ' ts2', 'from_stream', 'directly_from_stream',
#        'from_search', 'directly_from_search', 'from_quote_search',
#        'directly_from_quote_search', 'from_convo_search',
#        'directly_from_convo_search', 'from_timeline_search',
#        'directly_from_timeline_search', 'text', 'lang', 'author_id',
#        'author_handle', 'created_at', 'conversation_id', 'possibly_sensitive',
#        'reply_settings', 'source', 'author_follower_count', 'retweet_count',
#        'reply_count', 'like_count', 'quote_count', 'replied_to',
#        'replied_to_author_id', 'replied_to_handle',
#        'replied_to_follower_count', 'quoted', 'quoted_author_id',
#        'quoted_handle', 'quoted_follower_count', 'retweeted',
#        'retweeted_author_id', 'retweeted_handle', 'retweeted_follower_count',
#        'mentioned_author_ids', 'mentioned_handles', 'hashtags', 'urls',
#        'media_keys', 'place_id'],
#       dtype='object')

# %%
# Summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88037 entries, 0 to 88036
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             88037 non-null  int64
#  1   event                          88037 non-null  object
#  2   ts1                            88037 non-null  object
#  3    ts2                           88037 non-null  object
#  4   from_stream                    88037 non-null  bool
#  5   directly_from_stream           88037 non-null  bool
#  6   from_search                    88037 non-null  bool
#  7   directly_from_search           88037 non-null  bool
#  8   from_quote_search              88037 non-null  bool
#  9   directly_from_quote_search     88037 non-null  bool
#  10  from_convo_search              88037 non-null  bool
#  11  directly_from_convo_search     88037 non-null  bool
#  12  from_timeline_search           88037 non-null  bool
#  13  directly_from_timeline_search  88037 non-null  bool
#  14  text                           88037 non-null  object
#  15  lang                           88037 non-null  object
#  16  author_id                      88037 non-null  int64
#  17  author_handle                  88037 non-null  object
#  18  created_at                     88037 non-null  object
#  19  conversation_id                88037 non-null  int64
#  20  possibly_sensitive             88037 non-null  bool
#  21  reply_settings                 88037 non-null  object
#  22  source                         88037 non-null  object
#  23  author_follower_count          88037 non-null  int64
#  24  retweet_count                  88037 non-null  int64
#  25  reply_count                    88037 non-null  int64
#  26  like_count                     88037 non-null  int64
#  27  quote_count                    88037 non-null  int64
#  28  replied_to                     88037 non-null  object
#  29  replied_to_author_id           88037 non-null  object
#  30  replied_to_handle              88037 non-null  object
#  31  replied_to_follower_count      88037 non-null  object
#  32  quoted                         88037 non-null  object
#  33  quoted_author_id               88037 non-null  object
#  34  quoted_handle                  88037 non-null  object
#  35  quoted_follower_count          88037 non-null  object
#  36  retweeted                      88037 non-null  object
#  37  retweeted_author_id            88037 non-null  object
#  38  retweeted_handle               88037 non-null  object
#  39  retweeted_follower_count       88037 non-null  object
#  40  mentioned_author_ids           88037 non-null  object
#  41  mentioned_handles              88037 non-null  object
#  42  hashtags                       88037 non-null  object
#  43  urls                           88037 non-null  object
#  44  media_keys                     88037 non-null  object
#  45  place_id                       88037 non-null  object
# dtypes: bool(11), int64(8), object(27)
# memory usage: 24.4+ MB

# %%
# identify or cheking for missing value
df.isnull().sum()
# Out:
# id                               0
# event                            0
# ts1                              0
#  ts2                             0
# from_stream                      0
# directly_from_stream             0
# from_search                      0
# directly_from_search             0
# from_quote_search                0
# directly_from_quote_search       0
# from_convo_search                0
# directly_from_convo_search       0
# from_timeline_search             0
# directly_from_timeline_search    0
# text                             0
# lang                             0
# author_id                        0
# author_handle                    0
# created_at                       0
# conversation_id                  0
# possibly_sensitive               0
# reply_settings                   0
# source                           0
# author_follower_count            0
# retweet_count                    0
# reply_count                      0
# like_count                       0
# quote_count                      0
# replied_to                       0
# replied_to_author_id             0
# replied_to_handle                0
# replied_to_follower_count        0
# quoted                           0
# quoted_author_id                 0
# quoted_handle                    0
# quoted_follower_count            0
# retweeted                        0
# retweeted_author_id              0
# retweeted_handle                 0
# retweeted_follower_count         0
# mentioned_author_ids             0
# mentioned_handles                0
# hashtags                         0
# urls                             0
# media_keys                       0
# place_id                         0
# dtype: int64

# %%
# Statistical Summary
df.describe(include='all')
# Out:
#                   id           event                               ts1  \
# count   8.803700e+04           88037                             88037
# unique           NaN               1                             88037
# top              NaN  britney_201904  2022-02-28 09:34:44.627023-05:00
# freq             NaN           88037                                 1
# mean    1.128375e+18             NaN                               NaN
# std     3.001479e+15             NaN                               NaN
# min     1.101535e+18             NaN                               NaN
# 25%     1.126285e+18             NaN                               NaN
# 50%     1.128714e+18             NaN                               NaN
# 75%     1.130296e+18             NaN                               NaN
# max     1.134308e+18             NaN                               NaN
#
#                                      ts2 from_stream directly_from_stream  \
# count                              88037       88037                88037
# unique                             88037           1                    2
# top     2022-02-28 09:34:44.627023-05:00        True                 True
# freq                                   1       88037                84223
# mean                                 NaN         NaN                  NaN
# std                                  NaN         NaN                  NaN
# min                                  NaN         NaN                  NaN
# 25%                                  NaN         NaN                  NaN
# 50%                                  NaN         NaN                  NaN
# 75%                                  NaN         NaN                  NaN
# max                                  NaN         NaN                  NaN
#
#        from_search directly_from_search from_quote_search  \
# count        88037                88037             88037
# unique           1                    1                 1
# top          False                False             False
# freq         88037                88037             88037
# mean           NaN                  NaN               NaN
# std            NaN                  NaN               NaN
# min            NaN                  NaN               NaN
# 25%            NaN                  NaN               NaN
# 50%            NaN                  NaN               NaN
# 75%            NaN                  NaN               NaN
# max            NaN                  NaN               NaN
#
#        directly_from_quote_search  ... retweeted retweeted_author_id  \
# count                       88037  ...     88037               88037
# unique                          1  ...      4163                2751
# top                         False  ...      None                None
# freq                        88037  ...     36508               36508
# mean                          NaN  ...       NaN                 NaN
# std                           NaN  ...       NaN                 NaN
# min                           NaN  ...       NaN                 NaN
# 25%                           NaN  ...       NaN                 NaN
# 50%                           NaN  ...       NaN                 NaN
# 75%                           NaN  ...       NaN                 NaN
# max                           NaN  ...       NaN                 NaN
#
#        retweeted_handle retweeted_follower_count mentioned_author_ids  \
# count             88037                    88037                88037
# unique             2751                     2712                    1
# top                None                     None                 None
# freq              36508                    36508                88037
# mean                NaN                      NaN                  NaN
# std                 NaN                      NaN                  NaN
# min                 NaN                      NaN                  NaN
# 25%                 NaN                      NaN                  NaN
# 50%                 NaN                      NaN                  NaN
# 75%                 NaN                      NaN                  NaN
# max                 NaN                      NaN                  NaN
#
#        mentioned_handles  hashtags   urls media_keys  place_id
# count              88037     88037  88037      88037     88037
# unique                 1      2317  21731       6555       599
# top                 None      None   None       None      None
# freq               88037     75875  46396      71525     87016
# mean                 NaN       NaN    NaN        NaN       NaN
# std                  NaN       NaN    NaN        NaN       NaN
# min                  NaN       NaN    NaN        NaN       NaN
# 25%                  NaN       NaN    NaN        NaN       NaN
# 50%                  NaN       NaN    NaN        NaN       NaN
# 75%                  NaN       NaN    NaN        NaN       NaN
# max                  NaN       NaN    NaN        NaN       NaN
#
# [11 rows x 46 columns]

# %% [markdown]
# __Step 4: Convert created_at to DateTime Format__
# - The created_at column in the dataset contains timestamps that include timezone information.
# - We need to convert it to a datetime format that pandas can understand:

# %%
# Convert 'created_at' to datetime
df['created_at'] = pd.to_datetime(df['created_at'], utc=True)

# %% [markdown]
# __Step 5: Run the Query Function__

# %%
def query_data(term):
    # Filter for tweets containing the term
    term_tweets = df[df['text'].str.contains(term, case=False, na=False)]
    
    if term_tweets.empty:
        return f"No tweets found with the term '{term}'"

    # 1. How many tweets were posted containing the term on each day?
    tweets_per_day = term_tweets.groupby(term_tweets['created_at'].dt.date)['id'].count()

    # 2. How many unique users posted a tweet containing the term?
    unique_users = term_tweets['author_id'].nunique()

    # 3. How many likes did tweets containing the term get, on average?
    average_likes = term_tweets['like_count'].mean()

    # 4. Where (in terms of place IDs) did the tweets come from?
    unique_places = term_tweets['place_id'].unique()

    # 5. What times of day were the tweets posted at?
    term_tweets['hour'] = term_tweets['created_at'].dt.hour
    tweets_per_hour = term_tweets.groupby('hour')['id'].count()

    # 6. Which user posted the most tweets containing the term?
    most_active_user = term_tweets['author_id'].value_counts().idxmax()

    # Formatting the results for easy reading
    result = f"""
    Query Results for the term: '{term}'
    
    1. Number of tweets containing the term on each day:
    {tweets_per_day}
    
    2. Number of unique users who posted a tweet containing the term: {unique_users}
    
    3. Average likes for tweets containing the term: {average_likes}
    
    4. Place IDs from where the tweets were posted: {unique_places}
    
    5. Number of tweets posted at each hour of the day:
    {tweets_per_hour}
    
    6. User who posted the most tweets containing the term: {most_active_user}
    """
    
    return result


term = 'music'
print(query_data(term))
# Out:
#     Query Results for the term: 'music'
#
#     1. Number of tweets containing the term on each day:
#     created_at
# 2019-03-12      3
# 2019-04-06      1
# 2019-04-14      1
# 2019-04-16      1
# 2019-04-21      1
# 2019-04-24      1
# 2019-04-26      1
# 2019-04-27      3
# 2019-04-28     22
# 2019-04-29    118
# 2019-04-30    135
# 2019-05-01     71
# 2019-05-02     72
# 2019-05-03    103
# 2019-05-04     75
# 2019-05-05     65
# 2019-05-06     71
# 2019-05-07     64
# 2019-05-08     60
# 2019-05-09     70
# 2019-05-10    307
# 2019-05-11     78
# 2019-05-12     69
# 2019-05-13     50
# 2019-05-14     67
# 2019-05-15     99
# 2019-05-16     91
# 2019-05-17    162
# 2019-05-18     61
# 2019-05-19     46
# 2019-05-20     64
# 2019-05-21    119
# 2019-05-22     80
# 2019-05-23     73
# 2019-05-24     49
# 2019-05-25     92
# 2019-05-26    112
# 2019-05-27     76
# 2019-05-28     96
# 2019-05-29    187
# 2019-05-30     71
# 2019-05-31     14
# Name: id, dtype: int64
#
#     2. Number of unique users who posted a tweet containing the term: 2109
#
#     3. Average likes for tweets containing the term: 161.40853048983672
#
#     4. Place IDs from where the tweets were posted: ['None' '53504716d445dcad' 'ab2f2fac83aa388d' '0113afc024d5e0bc'
#  '300bcc6e23a88361' '8e9665cec9370f0f' 'd56c5babcffde8ef'
#  '01153d1b33e1641b' '09f6a7707f18e0b1' '714789cf3b7a50d0'
#  '01fbe706f872cb32' '1a7a70d4a28e96a1' 'f97108ab3c4a42ed'
#  'ac88a4f17a51c7fc' '5de8cffc145c486b' '3f7a925ec706ea48'
#  '001aff55522d96c9' '4c8e28554110ebcf' '5c62ffb0f0f3479d'
#  '3b77caf94bfc81fe' 'ecbe2aea853af44e' 'de599025180e2ee7'
#  '00b673715a35dfa7' '43d2418301bf1a49' '07e9c7d1954fff64'
#  '0570f015c264cbd9' '0149775319466b18' '91890dbb74364d63'
#  '01ddb0100b1efd97' 'b49b3053b5c25bf5' '7cb7440bcf83d464'
#  '151b9e91272233d1' '9d63050d3d33d32f' '140800566259f12f'
#  '743df94d8dcb69a6' '8bc4eeacf63235f9' '8943f93b51e3f357'
#  '2bc7c264a080898b' '814cfc71b843ff40' '2b8922cbe7f16337'
#  '7de31e05e99a00f8']
#
#     5. Number of tweets posted at each hour of the day:
#     hour
# 0     159
# 1     154
# 2     166
# 3     155
# 4     135
# 5     119
# 6      89
# 7      85
# 8      99
# 9      94
# 10     70
# 11     55
# 12    107
# 13    130
# 14    151
# 15    147
# 16    122
# 17    137
# 18    152
# 19    163
# 20    120
# 21    110
# 22    146
# 23    136
# Name: id, dtype: int64
#
#     6. User who posted the most tweets containing the term: 118301422
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_27624\3518202160.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   term_tweets['hour'] = term_tweets['created_at'].dt.hour

# %% [markdown]
# __analyzing how many tweets contain specific hashtags__

# %%
hashtag_count = df['hashtags'].value_counts()
hashtag_count.head(10)
# Out:
# None                 75875
# ['FreeBritney']       3923
# ['BritneySpears']      717
# ['jotafm']             281
# ['NowPlaying']         280
# ['freebritney']        222
# ['JanetJackson']       205
# ['FREEBRITNEY']        143
# ['RT']                 139
# ['WWHL']                95
# Name: hashtags, dtype: int64

# %% [markdown]
# __tweets containing certain words (like "music")__

# %%
music_tweets = df[df['text'].str.contains('music', case=False)]
music_tweets.head()
# Out:
#                       id           event                               ts1  \
# 89   1131558142569959424  britney_201904  2022-02-28 09:34:49.489632-05:00
# 191  1134153062384357378  britney_201904  2022-01-04 15:45:46.545877-05:00
# 275  1130933441191710720  britney_201904  2022-01-04 15:46:39.404655-05:00
# 339  1129818710095613952  britney_201904  2022-01-04 15:47:01.723682-05:00
# 341  1128705303862808577  britney_201904  2022-01-04 15:47:01.748329-05:00
#
#                                   ts2  from_stream  directly_from_stream  \
# 89   2022-02-28 09:34:49.489632-05:00         True                  True
# 191  2022-02-28 09:32:01.642704-05:00         True                  True
# 275  2022-02-28 09:35:43.998377-05:00         True                  True
# 339  2022-02-28 09:37:33.446307-05:00         True                  True
# 341  2022-02-28 09:40:48.913892-05:00         True                  True
#
#      from_search  directly_from_search  from_quote_search  \
# 89         False                 False              False
# 191        False                 False              False
# 275        False                 False              False
# 339        False                 False              False
# 341        False                 False              False
#
#      directly_from_quote_search  ...            retweeted  \
# 89                        False  ...                 None
# 191                       False  ...  1134149665606307841
# 275                       False  ...  1130654444495020032
# 339                       False  ...  1128705303862808577
# 341                       False  ...                 None
#
#      retweeted_author_id  retweeted_handle  retweeted_follower_count  \
# 89                  None              None                      None
# 191           4872315238   Bryan_KnowsBest                       308
# 275             16339785    musicdotjunkee                     32389
# 339  1030185143460397058    EatPrayBritney                      9329
# 341                 None              None                      None
#
#     mentioned_author_ids mentioned_handles         hashtags  urls media_keys  \
# 89                  None              None             None  None       None
# 191                 None              None             None  None       None
# 275                 None              None  ['FreeBritney']  None       None
# 339                 None              None             None  None       None
# 341                 None              None  ['FREEBRITNEY']  None       None
#
#      place_id
# 89       None
# 191      None
# 275      None
# 339      None
# 341      None
#
# [5 rows x 46 columns]

# %% [markdown]
# # Key Design Choices
#
# __1. Pandas for Data Handling:__
# - We use pandas to handle the dataset because it is fast, well-documented, and easy to use for data analysis and manipulation.
#
# __2. Search Functionality:__
# - The system filters tweets that contain a specific term, allowing for flexible searches. We use str.contains() to check if the term appears in the tweet's text.
#
# __3. Datetime Conversion:__
# - Converting the created_at column to datetime with utc=True is crucial to correctly handling timezone-aware timestamps. This ensures consistent time-based queries (e.g., by day, hour).
#
# __4. Efficient Grouping:__
# - We group tweets by day, hour, and users efficiently using groupby(), which is optimized for performance with large datasets.
#
# __5. User-Focused Results:__
# - We provide actionable insights (e.g., the most active user, average likes) to help users quickly understand trends.
